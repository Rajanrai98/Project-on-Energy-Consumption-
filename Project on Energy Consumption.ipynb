# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\Energy_consumption.csv")

# %%
data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# ...

# %%
data.head()
# Out:
#              Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0  2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1  2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2  2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3  2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4  2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
data.isnull().sum()
# Out:
# Timestamp            0
# Temperature          0
# Humidity             0
# SquareFootage        0
# Occupancy            0
# HVACUsage            0
# LightingUsage        0
# RenewableEnergy      0
# DayOfWeek            0
# Holiday              0
# EnergyConsumption    0
# dtype: int64

# %%
data["Timestamp"].value_counts()
# Out:
# 2022-01-01 00:00:00    1
# 2022-01-28 23:00:00    1
# 2022-01-28 10:00:00    1
# 2022-01-28 11:00:00    1
# 2022-01-28 12:00:00    1
#                       ..
# 2022-01-15 02:00:00    1
# 2022-01-15 03:00:00    1
# 2022-01-15 04:00:00    1
# 2022-01-15 05:00:00    1
# 2022-02-11 15:00:00    1
# Name: Timestamp, Length: 1000, dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.describe()
# Out:
#        Temperature     Humidity  SquareFootage    Occupancy  RenewableEnergy  \
# count  1000.000000  1000.000000    1000.000000  1000.000000      1000.000000
# mean     24.982026    45.395412    1500.052488     4.581000        15.132813
# std       2.836850     8.518905     288.418873     2.865598         8.745917
# min      20.007565    30.015975    1000.512661     0.000000         0.006642
# 25%      22.645070    38.297722    1247.108548     2.000000         7.628385
# 50%      24.751637    45.972116    1507.967426     5.000000        15.072296
# 75%      27.418174    52.420066    1740.340165     7.000000        22.884064
# max      29.998671    59.969085    1999.982252     9.000000        29.965327
#
#        EnergyConsumption
# count        1000.000000
# mean           77.055873
# std             8.144112
# min            53.263278
# 25%            71.544690
# 50%            76.943696
# 75%            82.921742
# max            99.201120

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Temperature  Humidity  SquareFootage  Occupancy  \
# Temperature           1.000000 -0.034032       0.004551  -0.003490
# Humidity             -0.034032  1.000000      -0.014651   0.004766
# SquareFootage         0.004551 -0.014651       1.000000   0.009696
# Occupancy            -0.003490  0.004766       0.009696   1.000000
# RenewableEnergy      -0.001350  0.002052       0.022196   0.013680
# EnergyConsumption     0.696410 -0.093583      -0.001129   0.186580
#
#                    RenewableEnergy  EnergyConsumption
# Temperature              -0.001350           0.696410
# Humidity                  0.002052          -0.093583
# ...

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# Temperature          0.088428
# Humidity            -0.066463
# SquareFootage       -0.019441
# Occupancy           -0.055229
# RenewableEnergy     -0.021597
# EnergyConsumption    0.027399
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# Temperature         -1.115196
# Humidity            -1.133748
# SquareFootage       -1.229895
# Occupancy           -1.233842
# RenewableEnergy     -1.220440
# EnergyConsumption   -0.300154
# dtype: float64

# %%
plt.figure(figsize = (12,8))
sn.heatmap(data.corr() , annot = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\1162485735.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr() , annot = True)
# <Axes: >

# %%
data.columns
# Out:
# Index(['Timestamp', 'Temperature', 'Humidity', 'SquareFootage', 'Occupancy',
#        'HVACUsage', 'LightingUsage', 'RenewableEnergy', 'DayOfWeek', 'Holiday',
#        'EnergyConsumption'],
#       dtype='object')

# %%
data = data.rename(columns = {"Timestamp":"timestamp","RenewableEnergy":"Rene_energy","LightingUsage":"lightusage","SquareFootage":"sqaurefootage" , "HVACUsage":"hvacusage"})

# %%
data
# Out:
#                timestamp  Temperature   Humidity  sqaurefootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
# ...

# %%
data.columns
# Out:
# Index(['timestamp', 'Temperature', 'Humidity', 'sqaurefootage', 'Occupancy',
#        'hvacusage', 'lightusage', 'Rene_energy', 'DayOfWeek', 'Holiday',
#        'EnergyConsumption'],
#       dtype='object')

# %%
for i in ['Temperature', 'Humidity', 'sqaurefootage', 'Rene_energy']:
    plt.boxplot(data[i])
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
plt.boxplot(data["EnergyConsumption"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19657b2a440>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19657b2b190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19657b2a140>],
#  'medians': [<matplotlib.lines.Line2D at 0x19657b29f30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19657b2a290>],
#  'means': []}

# %%
q1 =  data["EnergyConsumption"].quantile(0.25)
q3 = data["EnergyConsumption"].quantile(0.75)
iqr = q3-q1
upper_bound = q3+1.5*(iqr)
lower_bound = q1-1.5*(iqr)
print("upper_bound:",upper_bound)
print("lower_bound:",lower_bound)
# Out:
# upper_bound: 99.98731964403399
# lower_bound: 54.47911277617991

# %%
data = data[~(data["EnergyConsumption"]<lower_bound)| (data["EnergyConsumption"]>upper_bound)]

# %%
data
# Out:
#                timestamp  Temperature   Humidity  sqaurefootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
# ...

# %%
sn.distplot(data["EnergyConsumption"] , color = "red")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\581183372.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data["EnergyConsumption"] , color = "red")
# <Axes: xlabel='EnergyConsumption', ylabel='Density'>

# %%
data["EnergyConsumption"].skew()
# Out:
# 0.044236940102001035

# %%
for i in ['Temperature', 'Humidity', 'sqaurefootage']:
    sn.distplot(data[i],color = "green")
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\2938308326.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data[i],color = "green")
# C:\Users\user\AppData\Local\Temp\ipykernel_22648\2938308326.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sn.jointplot(x = "Temperature" , y = "EnergyConsumption" , data = data , color = "green")

# %%
for i in ['Temperature', 'Humidity']:
    sn.histplot(data[i] , color = "green")
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data =  data.apply(le.fit_transform)

# %%
data
# Out:
#      Timestamp  Temperature  Humidity  SquareFootage  Occupancy  HVACUsage  \
# 0            0          543       423            558          5          1
# 1            1          781       808            414          1          1
# 2            2          861       962            762          2          0
# 3            3            8       670            445          1          0
# 4            4          301       713             90          9          1
# ..         ...          ...       ...            ...        ...        ...
# 995        995          859       615             74          5          0
# 996        996          373       554            700          4          0
# 997        997          296       612            329          6          0
# 998        998          542        40            310          3          1
# 999        999          299       390             21          6          0
#
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp            0
# Temperature          0
# Humidity             0
# SquareFootage        0
# Occupancy            0
# HVACUsage            0
# LightingUsage        0
# RenewableEnergy      0
# DayOfWeek            0
# Holiday              0
# EnergyConsumption    0
# dtype: int64

# %%
x = data.drop(["EnergyConsumption"] , axis = 1)
y = data['EnergyConsumption']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
x_train , x_test ,y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((800, 10), (200, 10))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([735.29724372, 678.90952932, 498.67029777, 883.76991203,
#        425.141391  , 645.72738709, 555.21481959, 345.06275863,
#        548.79587257, 176.15159874, 569.8369526 , 366.6714382 ,
#        569.39591705, 577.94364023, 503.42825228, 289.30193151,
#        530.46292486, 558.62074698, 469.55998623, 118.25330343,
#        446.11313343, 407.28248591, 683.60659931, 553.96506042,
#        880.84176669, 371.93841974, 543.13424794, 280.47572315,
#        447.74019396, 631.2049809 , 236.09222269, 663.91974756,
#        371.13075692, 881.35342181, 549.36529626, 812.70078327,
#        800.42834687, 510.98851916, 563.89040852, 589.78596588,
#        459.14407621, 677.09216363, 201.10507248, 519.69874616,
#        401.83368052, 599.86660373, 522.14656382, 260.80224184,
#        333.74296385, 509.00663528, 521.3886013 , 750.51953539,
#        414.86480683, 286.23587989, 549.27649556, 920.05612827,
#        466.08138675, 544.57196423, 738.78891907, 413.00620415,
# ...

# %%
pd.DataFrame({"y_test":y_test , "y_pred": y_pred})
# Out:
#      y_test      y_pred
# 521     885  735.297244
# 737     915  678.909529
# 740     614  498.670298
# 660     937  883.769912
# 411     793  425.141391
# ..      ...         ...
# 408     884  814.883553
# 332     106  273.712724
# 208     647  628.921010
# 613     474  856.950522
# 78      131  146.717166
#
# [200 rows x 2 columns]

# %%
mse = np.mean((y_test-y_pred)**2)
print("mean_squared_value:",mse)
# Out:
# mean_squared_value: 33869.36850855878

# %%
rmse = np.sqrt(mse)
print("rmse_linear:",rmse)
# Out:
# rmse_linear: 184.036323883517

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor(criterion = "friedman_mse" , max_depth = 3)

# %%
model_tree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=3)

# %%
y_pred_tree = model_tree.predict(x_test)

# %%
y_pred_tree
# Out:
# array([709.35714286, 709.35714286, 330.8       , 729.80434783,
#        316.5859375 , 729.80434783, 543.67961165, 200.56349206,
#        541.01265823, 200.56349206, 541.01265823, 330.8       ,
#        541.01265823, 541.01265823, 543.67961165, 200.56349206,
#        316.5859375 , 543.67961165, 541.01265823, 200.56349206,
#        330.8       , 541.01265823, 541.01265823, 543.67961165,
#        848.20454545, 543.67961165, 543.67961165, 200.56349206,
#        541.01265823, 729.80434783, 316.5859375 , 729.80434783,
#        543.67961165, 848.20454545, 543.67961165, 848.20454545,
#        709.35714286, 543.67961165, 543.67961165, 541.01265823,
#        541.01265823, 709.35714286, 200.56349206, 330.8       ,
#        330.8       , 729.80434783, 541.01265823, 316.5859375 ,
#        200.56349206, 330.8       , 543.67961165, 848.20454545,
#        330.8       , 200.56349206, 543.67961165, 848.20454545,
#        543.67961165, 729.80434783, 709.35714286, 543.67961165,
# ...

# %%
pd.DataFrame({"y_test":y_test , "y_pred_tree":y_pred_tree})
# Out:
#      y_test  y_pred_tree
# 521     885   709.357143
# 737     915   709.357143
# 740     614   330.800000
# 660     937   729.804348
# 411     793   316.585938
# ..      ...          ...
# 408     884   729.804348
# 332     106   330.800000
# 208     647   709.357143
# 613     474   848.204545
# 78      131   200.563492
#
# [200 rows x 2 columns]

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (24,12))
plot_tree(model_tree , filled = True)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 0.249\nfriedman_mse = 83178.708\nsamples = 800\nvalue = 498.729'),
#  Text(0.25, 0.625, 'x[1] <= -0.648\nfriedman_mse = 50746.776\nsamples = 457\nvalue = 338.891'),
#  Text(0.125, 0.375, 'x[5] <= -0.008\nfriedman_mse = 33411.259\nsamples = 254\nvalue = 259.031'),
#  Text(0.0625, 0.125, 'friedman_mse = 29234.103\nsamples = 126\nvalue = 200.563'),
#  Text(0.1875, 0.125, 'friedman_mse = 30845.539\nsamples = 128\nvalue = 316.586'),
#  Text(0.375, 0.375, 'x[5] <= -0.008\nfriedman_mse = 54473.374\nsamples = 203\nvalue = 438.813'),
#  Text(0.3125, 0.125, 'friedman_mse = 45769.76\nsamples = 100\nvalue = 330.8'),
#  Text(0.4375, 0.125, 'friedman_mse = 40599.48\nsamples = 103\nvalue = 543.68'),
#  Text(0.75, 0.625, 'x[1] <= 0.944\nfriedman_mse = 46997.374\nsamples = 343\nvalue = 711.691'),
#  Text(0.625, 0.375, 'x[5] <= -0.008\nfriedman_mse = 50902.449\nsamples = 163\nvalue = 627.767'),
# ...

# %%
mse = np.mean((y_test - y_pred_tree)**2)
print("mse:",mse)
# Out:
# mse: 41848.19132552784

# %%
rmse = np.sqrt(mse)
print("rmse_tree:",rmse)
# Out:
# rmse_tree: 204.568304792135

# %%
model_forest = RandomForestRegressor(n_estimators = 100 , max_features = 5)

# %%
model_forest.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_features=5)

# %%
y_pred_forest = model_forest.predict(x_test)
print(y_pred_forest)
# Out:
# [753.24 689.33 512.88 822.24 382.33 732.76 560.43 292.31 565.29 192.19
#  593.55 307.91 598.38 594.24 545.88 357.63 452.67 529.54 490.87 139.37
#  393.77 344.57 630.55 584.56 723.18 324.52 544.7  315.66 448.19 731.77
#  206.74 603.61 407.41 774.59 541.13 815.73 802.6  522.09 561.31 559.78
#  426.65 737.04 226.57 464.82 326.99 661.15 489.18 270.56 378.97 532.42
#  501.35 673.56 318.13 355.4  506.55 829.67 465.46 502.26 718.52 510.78
#  159.91 825.12 290.4  183.77 223.96 700.96 430.7  220.25 246.38 334.62
#  254.95 684.52 189.76 664.09 785.75 850.5  722.49 348.19 592.66 406.27
#  544.18 431.02 248.36 475.13 688.2  132.76 588.12 433.3  171.6  233.22
#  574.2  190.39 254.4  718.57 194.22 812.24 382.4  412.95 459.3  775.57
#  640.91 645.54 299.6  845.13 413.72 249.84 557.78 679.55 659.92 517.23
#  717.9  528.72 678.91 726.98 140.8  557.54 609.7  571.06 223.3  138.54
#  631.33 796.37 614.55 395.69 222.1  134.11 602.94 459.97 439.38 587.31
# ...

# %%
pd.DataFrame({"y_test":y_test , "y_pred_forest":y_pred_forest})
# Out:
#      y_test  y_pred_forest
# 521     885         753.24
# 737     915         689.33
# 740     614         512.88
# 660     937         822.24
# 411     793         382.33
# ..      ...            ...
# 408     884         766.43
# 332     106         236.09
# 208     647         649.52
# 613     474         847.62
# 78      131         128.05
#
# [200 rows x 2 columns]

# %%
mse = np.mean((y_test-y_pred_forest)**2)
print("mean_squared_error:",mse)
# Out:
# mean_squared_error: 36439.171289000005

# %%
rmse = np.sqrt(mse)
print("rmse_random:",rmse)
# Out:
# rmse_random: 190.89046935088197

# %%
data.shape
# Out:
# (1000, 11)

# %%
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

# %%
model = Sequential()
model.add(Dense(12 ,input_dim = 10 , activation = "relu" ))
model.add(Dense(22 , activation = "relu"))
model.add(Dense(14 , activation = "relu"))
model.add(Dense(6 , activation = "relu"))
model.add(Dense(1 , activation = "linear"))

# %%
model.compile(loss = "mean_squared_error" , optimizer = "adam")

# %%
history = model.fit(x_train , y_train , batch_size = 32 , epochs = 200 , validation_split = 0.20)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 0s 9ms/step - loss: 24703.7031 - val_loss: 38146.0508
# Epoch 2/200
# 20/20 [==============================] - 0s 6ms/step - loss: 24819.7832 - val_loss: 38084.6055
# Epoch 3/200
# 20/20 [==============================] - 0s 5ms/step - loss: 24661.4395 - val_loss: 38184.4102
# Epoch 4/200
# 20/20 [==============================] - 0s 5ms/step - loss: 24760.8535 - val_loss: 38227.2539
# Epoch 5/200
# 20/20 [==============================] - 0s 5ms/step - loss: 24717.0371 - val_loss: 38122.9609
# Epoch 6/200
# 20/20 [==============================] - 0s 6ms/step - loss: 24735.3965 - val_loss: 38228.3320
# Epoch 7/200
# 20/20 [==============================] - 0s 6ms/step - loss: 24820.1738 - val_loss: 38124.6250
# Epoch 8/200
# 20/20 [==============================] - 0s 6ms/step - loss: 24755.3301 - val_loss: 38215.4297
# Epoch 9/200
# 20/20 [==============================] - 0s 5ms/step - loss: 24661.4570 - val_loss: 38106.0977
# ...

# %%
from sklearn.linear_model import Lasso

# %%
alpha = 0.01
model_lasso = Lasso(alpha = alpha)
model_lasso.fit(x_train , y_train)
# Out:
# Lasso(alpha=0.01)

# %%
y_pred_lasso = model_lasso.predict(x_test)

# %%
pd.DataFrame({"y_test":y_test , "y_pred_lasso":y_pred_lasso})
# Out:
#      y_test  y_pred_lasso
# 521     885    735.264500
# 737     915    678.917058
# 740     614    498.653629
# 660     937    883.735465
# 411     793    425.151143
# ..      ...           ...
# 408     884    814.873313
# 332     106    273.768921
# 208     647    628.935068
# 613     474    856.894223
# 78      131    146.761276
#
# [200 rows x 2 columns]

# %%
mse = np.mean((y_test - y_pred_lasso)**2)
rmse = np.sqrt(mse)
print("rmse_lasso:",rmse)
# Out:
# rmse_lasso: 184.03349506869807

# %%
sn.pairplot(data)

# %%
sn.jointplot(x = "EnergyConsumption" , y = "Humidity",data = data,  kind = "kde")

# %%
plt.figure(figsize = (24,8))
sn.lineplot(data["EnergyConsumption"] , color = "red")
# Out:
# <Axes: ylabel='EnergyConsumption'>

# %%
plt.scatter(x = "RenewableEnergy" , y = "EnergyConsumption" , data = data , color = "green")
plt.title("scatterplot")
plt.xlabel("RenewableEnergy")
plt.ylabel("EnergyConsumption")
# Out:
# Text(0, 0.5, 'EnergyConsumption')
